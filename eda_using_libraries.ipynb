# %%
from libraries.import_export_data_objects import import_export_data as Import_Export_Data
from libraries.altair_renderings import AltairRenderings
from libraries.utility import Utility
import os
import altair as alt
my_altair = AltairRenderings()
my_data = Import_Export_Data()

# %%
my_altair.get_china_section_1()

# %%
my_altair.get_nafta_section_1_1()
# Out:
# alt.VConcatChart(...)

# %%
my_data.get_nafta_by_country()
# Out:
#             Country  Year  GDP Growth Pct  Trade Pct GDP  TradePctGDPChange  \
# 0         Australia  2000        3.912428      40.994103                NaN
# 1         Australia  2001        2.038301      44.282367           3.288264
# 2         Australia  2002        4.014527      41.496654          -2.785714
# 3         Australia  2003        3.110325      40.231524          -1.265130
# 4         Australia  2004        4.205447      37.039362          -3.192162
# ..              ...   ...             ...            ...                ...
# 471  United Kingdom  2018        1.650925      62.314223           0.959466
# 472  United Kingdom  2019        1.671944      62.927269           0.613046
# 473  United Kingdom  2019        1.671944      62.927269           0.613046
# 474  United Kingdom  2020       -9.396160      56.108854          -6.818415
# 475  United Kingdom  2020       -9.396160      56.108854          -6.818415
#
#             country    year  total_trade    exports  net_exports    imports  \
# 0              None     NaN          NaN        NaN          NaN        NaN
# 1              None     NaN          NaN        NaN          NaN        NaN
# 2              None     NaN          NaN        NaN          NaN        NaN
# 3              None     NaN          NaN        NaN          NaN        NaN
# 4              None     NaN          NaN        NaN          NaN        NaN
# ..              ...     ...          ...        ...          ...        ...
# 471  United Kingdom  2018.0   1563716.07  634165.49   -295385.13  929550.56
# 472  United Kingdom  2019.0    161844.49   72928.66    -15987.17   88915.83
# 473  United Kingdom  2019.0   1516111.68  583979.87   -348151.90  932131.77
# 474  United Kingdom  2020.0    134937.16   58211.25    -18514.66   76725.91
# 475  United Kingdom  2020.0   1336988.19  514545.13   -307898.05  822443.17
#
#          isChinaPartner  total_toWorld_trade  total_toWorld_exports  \
# 0                  None                  NaN                    NaN
# 1                  None                  NaN                    NaN
# 2                  None                  NaN                    NaN
# 3                  None                  NaN                    NaN
# 4                  None                  NaN                    NaN
# ..                  ...                  ...                    ...
# 471  Trades with Others           1716373.16              704939.60
# 472   Trades with NAFTA           1677956.17              656908.53
# 473  Trades with Others           1677956.17              656908.53
# 474   Trades with NAFTA           1471925.35              572756.38
# 475  Trades with Others           1471925.35              572756.38
#
#      total_toWorld_imports  total_toWorld_net_exports  china_target_pct_chg
# 0                      NaN                        NaN                   NaN
# 1                      NaN                        NaN                   NaN
# 2                      NaN                        NaN                   NaN
# 3                      NaN                        NaN                   NaN
# 4                      NaN                        NaN                   NaN
# ..                     ...                        ...                   ...
# 471             1011433.54                 -306494.00              0.822117
# 472             1021047.60                 -364139.07             -0.814605
# 473             1021047.60                 -364139.07              0.807093
# 474              899169.08                 -326412.71             -0.811873
# 475              899169.08                 -326412.71              0.816652
#
# [476 rows x 17 columns]

# %%
my_altair.get_eu_section_1()
# Out:
# /Users/adonisirwin/system_data_folder/00AA_SCHOOL/MIDS/w209/w209_spring_2022_thu_4_pm_team_4_web/libraries/altair_renderings.py:1187: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   non_eu = non_eu.groupby(by=['country','year'])['Total Trade ($M)','Exports ($M)','Imports ($M)'].sum()
# alt.HConcatChart(...)

# %%
#print(my_data.get_gdp_data_by_country("United States").head())
my_altair.get_time_series_gdp_chart("United States")
# Out:
# alt.LayerChart(...)

# %%
my_altair.get_time_series_gdp_compare_chart("United States","China")
# Out:
# alt.LayerChart(...)

# %%
from libraries.import_export_data_objects import import_export_data as Import_Export_Data
from libraries.altair_renderings import AltairRenderings
from libraries.utility import Utility
import os
import altair as alt
my_altair = AltairRenderings()
my_data = Import_Export_Data()

source_country = "United States"
target_country = "China"



my_chart = my_altair.get_charts_for_click_from_world_map(source_country)
my_chart

my_chart = my_altair.get_charts_for_country_dill_down(source_country,target_country,width=350,height=200)
my_chart

print(my_data.load_exchange_rate_data().head(10))

print(my_data.load_and_clean_up_top_20_file().head(10))
print(my_data.load_and_clean_up_WTO_file().head(10))
print(my_data.load_and_clean_up_GDP_file().head(10))
# Out:
#      Country  year      rate
# 0  Australia  2000  1.724827
# 1  Australia  2001  1.933443
# 2  Australia  2002  1.840563
# 3  Australia  2003  1.541914
# 4  Australia  2004  1.359752
# 5  Australia  2005  1.309473
# 6  Australia  2006  1.327973
# 7  Australia  2007  1.195073
# 8  Australia  2008  1.192178
# 9  Australia  2009  1.282189
#   Trading Partner  Total Trade ($M)  RtW (%)  Exports ($M)  RtW (%).1  \
# 0           China         139714.00    28.28      90132.20      35.67
# 1           Japan          64576.70    13.07      48127.30      19.05
# 2   United States          36313.10     7.35      10671.80       4.22
# 3       Singapore          16781.17     3.40       4681.27       1.85
# 4         Germany          13112.55     2.65       1770.85       0.70
# 5           India          12958.48     2.62      10004.10       3.96
# 6     New Zealand          12698.44     2.57       5188.15       2.05
# 7       Indonesia          11558.85     2.34       5647.50       2.24
# 8  United Kingdom           9082.87     1.84       3268.89       1.29
# 9           Italy           6448.65     1.31        680.12       0.27
#
#    Imports ($M)  RtW (%).2  Net Exports ($M)  Exports Ticker  Imports Ticker  \
# 0      49581.80      20.54          40550.40  924D1193 Index  193D1924 Index
# 1      16449.40       6.81          31677.90  158D1193 Index  193D1158 Index
# 2      25641.30      10.62         -14969.50  111D1193 Index  193D1111 Index
# 3      12099.90       5.01          -7418.63  576D1193 Index  193D1576 Index
# 4      11341.70       4.70          -9570.85  134D1193 Index  193D1134 Index
# 5       2954.38       1.22           7049.72  534D1193 Index  193D1534 Index
# 6       7510.29       3.11          -2322.14  196D1193 Index  193D1196 Index
# 7       5911.35       2.45           -263.85  536D1193 Index  193D1536 Index
# 8       5813.98       2.41          -2545.09  112D1193 Index  193D1112 Index
# 9       5768.53       2.39          -5088.41  136D1193 Index  193D1136 Index
#
#      country  year  country_exchange_rate  trading_partner_exchange_rate
# 0  Australia  2014               1.109363                       6.143434
# 1  Australia  2014               1.109363                     105.944781
# 2  Australia  2014               1.109363                       1.000000
# 3  Australia  2014               1.109363                       1.267050
# 4  Australia  2014               1.109363                       0.752728
# 5  Australia  2014               1.109363                      61.029514
# 6  Australia  2014               1.109363                       1.205433
# 7  Australia  2014               1.109363                   11865.211296
# 8  Australia  2014               1.109363                       0.607730
# 9  Australia  2014               1.109363                       0.752728
#   Reporting Economy                    Product/Sector Partner Economy  Year  \
# 0         Australia  SI3_AGG - TO - Total merchandise           World  2014
# 1         Australia  SI3_AGG - TO - Total merchandise           World  2014
# 2         Australia  SI3_AGG - TO - Total merchandise           World  2014
# 3         Australia  SI3_AGG - TO - Total merchandise           World  2014
# 4         Australia  SI3_AGG - TO - Total merchandise           World  2014
# 5         Australia  SI3_AGG - TO - Total merchandise           World  2014
# 6         Australia  SI3_AGG - TO - Total merchandise           World  2014
# 7         Australia  SI3_AGG - TO - Total merchandise           World  2014
# 8         Australia  SI3_AGG - TO - Total merchandise           World  2014
# 9         Australia  SI3_AGG - TO - Total merchandise           World  2014
#
#       Value Product/Sector-reformatted         Type Direction  \
# 0  239975.0          Total merchandise  merchandise   exports
# 1  239975.0          Total merchandise  merchandise   exports
# 2  239975.0          Total merchandise  merchandise   exports
# 3  239975.0          Total merchandise  merchandise   exports
# 4  239975.0          Total merchandise  merchandise   exports
# 5  239975.0          Total merchandise  merchandise   exports
# 6  239975.0          Total merchandise  merchandise   exports
# 7  239975.0          Total merchandise  merchandise   exports
# 8  239975.0          Total merchandise  merchandise   exports
# 9  239975.0          Total merchandise  merchandise   exports
#
#    reporting_economy_exchange_rate partner_economy_exchange_rate
# 0                         0.965801                          None
# 1                         0.969463                          None
# 2                         1.035843                          None
# 3                         1.090159                          None
# 4                         1.109363                          None
# 5                         1.192178                          None
# 6                         1.195073                          None
# 7                         1.282189                          None
# 8                         1.304758                          None
# 9                         1.309473                          None
#      Country Metric Year  Year  AFF value added  Deposit interest rate pct  \
# 0  Argentina  2000-01-01  2000         4.679911                        0.0
# 1  Argentina  2001-01-01  2001         4.568590                        0.0
# 2  Argentina  2002-01-01  2002        10.206647                        0.0
# 3  Argentina  2003-01-01  2003        10.328167                        0.0
# 4  Argentina  2004-01-01  2004         8.362487                        0.0
# 5  Argentina  2005-01-01  2005         7.938754                        0.0
# 6  Argentina  2006-01-01  2006         6.935572                        0.0
# 7  Argentina  2007-01-01  2007         7.452354                        0.0
# 8  Argentina  2008-01-01  2008         7.318955                        0.0
# 9  Argentina  2009-01-01  2009         5.273623                        0.0
#
#    Exports G & S Pct GDP  Exports G & S Pct US dollar  \
# 0                  10.99                 3.123692e+10
# 1                  11.58                 3.111675e+10
# 2                  28.38                 2.905450e+10
# 3                  25.93                 3.433601e+10
# 4                  23.85                 3.975725e+10
# 5                  23.25                 4.689221e+10
# 6                  23.03                 5.452852e+10
# 7                  22.66                 6.612230e+10
# 8                  22.06                 8.158362e+10
# 9                  19.56                 6.633561e+10
#
#    Exports G & S Pct constant LCU  Exports G & S annual growth %  \
# 0                    9.531203e+10                       2.702391
# 1                    9.792452e+10                       2.740991
# 2                    1.009533e+11                       3.092955
# 3                    1.070058e+11                       5.995368
# 4                    1.156884e+11                       8.114158
# 5                    1.305970e+11                      12.886830
# 6                    1.378598e+11                       5.561203
# 7                    1.491153e+11                       8.164452
# 8                    1.502185e+11                       0.739874
# 9                    1.361774e+11                      -9.347106
#
#    External balance on G & S pct GDP  ...  GDP Pct Growth  \
# 0                          -0.649694  ...           -0.79
# 1                           1.305761  ...           -4.41
# 2                          15.012470  ...          -10.89
# 3                          11.217138  ...            8.84
# 4                           7.002593  ...            9.03
# 5                           5.940482  ...            8.85
# 6                           5.619909  ...            8.05
# 7                           4.380330  ...            9.01
# 8                           3.719127  ...            4.06
# 9                           5.064843  ...           -5.92
#
#    Imports G & S Pct GDP  Net Trade Pct GDP  Trade Pct GDP %   Trade Total  \
# 0                  11.64              -0.65             0.23  6.536686e+10
# 1                  10.27               1.31             0.22  5.911328e+10
# 2                  13.37              15.01             0.42  4.104408e+10
# 3                  14.71              11.22             0.41  5.231066e+10
# 4                  16.85               7.00             0.41  6.750975e+10
# 5                  17.31               5.94             0.41  8.148221e+10
# 6                  17.41               5.62             0.40  9.302290e+10
# 7                  18.28               4.38             0.41  1.178875e+11
# 8                  18.34               3.72             0.40  1.446232e+11
# 9                  14.50               5.06             0.34  1.132120e+11
#
#    Prev Year  Year_curr  Trade Total Change  Trade Total Change %  \
# 0       1999       2000                 NaN                   NaN
# 1       2000       2001       -6.253578e+09                 -9.57
# 2       2001       2002       -1.806920e+10                -30.57
# 3       2002       2003        1.126658e+10                 27.45
# 4       2003       2004        1.519909e+10                 29.06
# 5       2004       2005        1.397246e+10                 20.70
# 6       2005       2006        1.154070e+10                 14.16
# 7       2006       2007        2.486460e+10                 26.73
# 8       2007       2008        2.673571e+10                 22.68
# 9       2008       2009       -3.141121e+10                -21.72
#
#    exchange_rate
# 0       0.999500
# 1       0.999500
# 2       3.063257
# 3       2.900629
# 4       2.923301
# 5       2.903658
# 6       3.054313
# 7       3.095649
# 8       3.144165
# 9       3.710107
#
# [10 rows x 90 columns]

# %%
my_altair.get_altaire_bar_top5_partners(source_country)
# Out:
# alt.LayerChart(...)

# %%
import altair as alt
from vega_datasets import data

source = data.cars()

# Brush for selection
brush = alt.selection(type='interval')

# Scatter Plot
points = alt.Chart(source).mark_point().encode(
    x='Horsepower:Q',
    y='Miles_per_Gallon:Q',
    color=alt.condition(brush, 'Cylinders:O', alt.value('grey'))
).add_selection(brush)

# Base chart for data tables
ranked_text = alt.Chart(source).mark_text().encode(
    y=alt.Y('row_number:O',axis=None)
).transform_window(
    row_number='row_number()'
).transform_filter(
    brush
).transform_window(
    rank='rank(row_number)'
).transform_filter(
    alt.datum.rank<20
)

# Data Tables
horsepower = ranked_text.encode(text='Horsepower:N').properties(title='Horsepower')
mpg = ranked_text.encode(text='Miles_per_Gallon:N').properties(title='MPG')
origin = ranked_text.encode(text='Origin:N').properties(title='Origin')
text = alt.hconcat(horsepower, mpg, origin) # Combine data tables

# Build chart
alt.hconcat(
    points,
    text
).resolve_legend(
    color="independent"
)
# Out:
# alt.HConcatChart(...)

# %%
import altair as alt
from vega_datasets import data

source = data.population.url

pink_blue = alt.Scale(domain=('Male', 'Female'),
                      range=["steelblue", "salmon"])

slider = alt.binding_range(min=1900, max=2000, step=10)
select_year = alt.selection_single(name="year", fields=['year'],
                                   bind=slider, init={'year': 2000})

alt.Chart(source).mark_bar().encode(
    x=alt.X('sex:N', title=None),
    y=alt.Y('people:Q', scale=alt.Scale(domain=(0, 12000000))),
    color=alt.Color('sex:N', scale=pink_blue),
    column='age:O'
).properties(
    width=20
).add_selection(
    select_year
).transform_calculate(
    "sex", alt.expr.if_(alt.datum.sex == 1, "Male", "Female")
).transform_filter(
    select_year
).configure_facet(
    spacing=8
)

# %%
top5_partners

# %%
my_data_object = Import_Export_Data()

exports_data = my_data_object.get_top5data_by_imports_exports(source_country, 'exports')
exports_data.head(1000)

# %%
my_data_object.get_top_trading_and_net_value("Australia").head(100)

# %%
my_altair.get_import_export_balance_top_five("Australia")

# %%
from vega_datasets import data
import numpy as np

world_map_source = alt.topo_feature(data.world_110m.url, 'countries')



country_source = my_data_object.get_world_countries_by_iso_label()


foreground = (
    alt.Chart(world_map_source)
    .mark_geoshape(fill='lightgray', stroke="black", strokeWidth=1)
    .encode(
        tooltip=[
            alt.Tooltip("Country:N", title="Country")
        ],
    )
    .transform_lookup(
        lookup="id",
        from_=alt.LookupData(country_source, "id", ["Country"]),
    )
)

my_map = (
    (foreground)
    .configure_view(strokeWidth=0)
    .properties(width=900, height=400)
    .project("mercator", scale=185,center=np.array([24,12]))
)
#my_map = alt.concat(my_map,scale=160)

utility = Utility()
this_dir = utility.get_this_dir()
file_name = os.path.join(this_dir,"libraries","world.json")
my_json = utility.get_data_from_file(file_name)
#return my_json,my_map
my_map

# %%
my_altair.my_new_map()
