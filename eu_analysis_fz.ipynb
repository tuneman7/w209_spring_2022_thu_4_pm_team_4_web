# %%
from libraries.import_export_data_objects import import_export_data as Import_Export_Data
from libraries.altair_renderings import AltairRenderings
from libraries.utility import Utility
import pandasql as psql
import numpy as np
import pandas as pd
import os
import altair as alt
my_altair = AltairRenderings()
my_data = Import_Export_Data()

# %%
my_altair.get_eu_domestic_trading_chart()
# Out:
# alt.Chart(...)

# %%
my_altair.get_eu_versus_noneu_trading_chart()
# Out:
# /Users/Stan/Desktop/UCB_MIDS/W209/w209_spring_2022_thu_4_pm_team_4_web/libraries/altair_renderings.py:1186: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   non_eu = non_eu.groupby(by=['country','year'])['Total Trade ($M)','Exports ($M)','Imports ($M)'].sum()
# alt.HConcatChart(...)

# %%
df = my_data.get_EUdata_by_country()

# %%
df = df[df['isEuPartner'].isin(['Trades with EU','Trades with Others'])]

# %%
df_2020['isEuPartner'].unique()
# Out:
# array(['Trades with EU', 'Trades with Others'], dtype=object)

# %%
df_2020 = df[df['Year']==2020]
df_2020
# Out:
#             Country  Year  GDP Growth Pct  Trade Pct GDP  TradePctGDPChange  \
# 32        Australia  2020       -0.003837      44.039526          -1.805514
# 34        Australia  2020       -0.003837      44.039526          -1.805514
# 67           Brazil  2020       -4.059048      32.354296           3.898359
# 69           Brazil  2020       -4.059048      32.354296           3.898359
# 102          Canada  2020       -5.233024      60.782530          -4.629832
# 104          Canada  2020       -5.233024      60.782530          -4.629832
# 137           China  2020        2.347514      34.506888          -1.383208
# 139           China  2020        2.347514      34.506888          -1.383208
# 172          France  2020       -7.855256      57.767428          -6.374045
# 174          France  2020       -7.855256      57.767428          -6.374045
# 207         Germany  2020       -4.569617      81.108547          -6.491119
# 209         Germany  2020       -4.569617      81.108547          -6.491119
# 242           India  2020       -7.251755      37.870998          -1.515773
# 244           India  2020       -7.251755      37.870998          -1.515773
# 277       Indonesia  2020       -2.069543      33.190589          -4.258191
# 279       Indonesia  2020       -2.069543      33.190589          -4.258191
# 312            Iran  2020        3.388262      51.294367          -4.878695
# 314            Iran  2020        3.388262      51.294367          -4.878695
# 347           Italy  2020       -8.938593      55.085296          -4.867569
# 349           Italy  2020       -8.938593      55.085296          -4.867569
# 382           Japan  2020       -4.585508      31.072693          -3.688286
# 384           Japan  2020       -4.585508      31.072693          -3.688286
# 417          Mexico  2020       -8.309035      78.195822           0.312963
# 419          Mexico  2020       -8.309035      78.195822           0.312963
# 452     Netherlands  2020       -3.798636     145.304620          -9.966057
# 453     Netherlands  2020       -3.798636     145.304620          -9.966057
# 487          Russia  2020       -2.951274      46.083080          -3.361300
# 489          Russia  2020       -2.951274      46.083080          -3.361300
# 522    Saudi Arabia  2020       -4.106583      50.602380         -13.057378
# 524    Saudi Arabia  2020       -4.106583      50.602380         -13.057378
# 558     South Korea  2020       -0.852031      69.215521          -6.541618
# 559     South Korea  2020       -0.852031      69.215521          -6.541618
# 592           Spain  2020      -10.822886      59.768724          -7.210603
# 593           Spain  2020      -10.822886      59.768724          -7.210603
# 627     Switzerland  2020       -2.392826     115.889400          -3.326137
# 699   United States  2020.0   2963381.90  1077966.76   -807448.43  1885415.21
#
#             isEuPartner  total_toWorld_trade  total_toWorld_exports  \
# 32       Trades with EU            505928.65              263556.91
# 34   Trades with Others            505928.65              263556.91
# 67       Trades with EU            442255.62              261099.00
# 69   Trades with Others            442255.62              261099.00
# 102      Trades with EU            878794.56              411128.05
# 104  Trades with Others            878794.56              411128.05
# 137      Trades with EU           4922192.24             2934550.65
# 139  Trades with Others           4922192.24             2934550.65
# 172  Trades with Others           1743505.04              781175.42
# 174      Trades with EU           1743505.04              781175.42
# 207  Trades with Others           3982877.08             2080323.50
# 209      Trades with EU           3982877.08             2080323.50
# 242      Trades with EU            703089.77              306317.89
# 244  Trades with Others            703089.77              306317.89
# 277      Trades with EU            343661.40              195690.77
# 279  Trades with Others            343661.40              195690.77
# 312      Trades with EU             38704.27               14472.11
# 314  Trades with Others             38704.27               14472.11
# 347  Trades with Others           1415141.99              742590.13
# 349      Trades with EU           1415141.99              742590.13
# 382      Trades with EU           1400572.01              724254.17
# 384  Trades with Others           1400572.01              724254.17
# 417      Trades with EU            901798.30              463748.69
# 419  Trades with Others            901798.30              463748.69
# 452  Trades with Others           1819642.19              992144.93
# 453      Trades with EU           1819642.19              992144.93
# 487      Trades with EU            752242.48              444633.83
# 489  Trades with Others            752242.48              444633.83
# 522      Trades with EU            349342.52              191253.44
# 524  Trades with Others            349342.52              191253.44
# 558      Trades with EU           1106375.51              604818.45
# 559  Trades with Others           1106375.51              604818.45
# 592  Trades with Others            990557.53              475743.72
# 593      Trades with EU            990557.53              475743.72
# 627      Trades with EU            871539.55              438392.81
# 629  Trades with Others            871539.55              438392.81
# 663      Trades with EU           1471925.35              572756.38
# 664  Trades with Others           1471925.35              572756.38
# 697      Trades with EU           4269862.30             1581491.76
# 699  Trades with Others           4269862.30             1581491.76
#
#      total_toWorld_imports  total_toWorld_net_exports  eu_target_pct_chg
# 32               242371.78                   21185.23          -0.024954
# 34               242371.78                   21185.23           0.727530
# 67               181156.65                   79942.41          -0.006560
# 69               181156.65                   79942.41           0.607453
# 102              467666.57                  -56538.52          -0.016930
# 104              467666.57                  -56538.52           0.742175
# 137             1987641.61                  946909.05          -0.009397
# 139             1987641.61                  946909.05           0.564120
# 172              962329.80                 -181154.34          -0.122720
# 174              962329.80                 -181154.34           0.000351
# 207             1902553.59                  177769.96          -0.100672
# 209             1902553.59                  177769.96           0.008203
# 242              396771.94                  -90454.04          -0.012071
# 244              396771.94                  -90454.04           0.684600
# 277              147970.74                   47720.10          -0.004888
# 279              147970.74                   47720.10           0.774073
# 312               24232.17                   -9760.10          -0.002295
# 314               24232.17                   -9760.10           0.658982
# 347              672551.83                   70038.31          -0.040337
# 349              672551.83                   70038.31           0.011818
# 382              676317.92                   47936.13          -0.003381
# 384              676317.92                   47936.13           0.708014
# 417              438049.59                   25699.13          -0.001372
# 419              438049.59                   25699.13           0.779846
# 452              827497.28                  164647.62          -0.115576
# 453              827497.28                  164647.62          -0.017083
# 487              307608.66                  137025.28          -0.009024
# 489              307608.66                  137025.28           0.247200
# 522              158089.00                   33164.44          -0.004378
# 524              158089.00                   33164.44           0.605983
# 558              501557.12                  103261.45           0.000779
# 559              501557.12                  103261.45           0.714690
# 592              514813.88                  -39070.21          -0.124819
# 593              514813.88                  -39070.21          -0.006973
# 627              433146.81                    5246.03          -0.009769
# 629              433146.81                    5246.03           0.062180
# 663              899169.08                 -326412.71           0.040931
# 664              899169.08                 -326412.71           0.060153
# 697             2688370.61                -1106878.83          -0.002948
# 699             2688370.61                -1106878.83           0.542508

# %%
df_2020_new_total = df_2020.groupby(by=['country','year'])['total_trade'].sum()
df_2020_new_total = df_2020_new_total.reset_index()
new_df = pd.merge(df_2020, df_2020_new_total,  how='left', left_on=['country','year'], right_on=['country','year'])
new_df.head()
# Out:
#      Country  Year  GDP Growth Pct  Trade Pct GDP  TradePctGDPChange  \
# 0  Australia  2020       -0.003837      44.039526          -1.805514
# 1  Australia  2020       -0.003837      44.039526          -1.805514
# 2     Brazil  2020       -4.059048      32.354296           3.898359
# 3     Brazil  2020       -4.059048      32.354296           3.898359
# 4     Canada  2020       -5.233024      60.782530          -4.629832
#
#      country    year  total_trade_x    exports  net_exports    imports  \
# 0  Australia  2020.0       41741.86    7769.76    -26202.34   33972.10
# 1  Australia  2020.0      409820.19  237846.50     65872.90  171973.72
# 2     Brazil  2020.0       56901.60   28470.80        40.00   28430.80
# 3     Brazil  2020.0      325551.08  202379.49     79207.93  123171.64
# 4     Canada  2020.0       70565.70   23405.80    -23754.10   47159.90
#
#           isEuPartner  total_toWorld_trade  total_toWorld_exports  \
# 0      Trades with EU            505928.65              263556.91
# 1  Trades with Others            505928.65              263556.91
# 2      Trades with EU            442255.62              261099.00
# 3  Trades with Others            442255.62              261099.00
# 4      Trades with EU            878794.56              411128.05
#
#    total_toWorld_imports  total_toWorld_net_exports  eu_target_pct_chg  \
# 0              242371.78                   21185.23          -0.024954
# 1              242371.78                   21185.23           0.727530
# 2              181156.65                   79942.41          -0.006560
# 3              181156.65                   79942.41           0.607453
# 4              467666.57                  -56538.52          -0.016930
#
#    total_trade_y
# 0      451562.05
# 1      451562.05
# 2      382452.68
# 3      382452.68
# 4      793351.08

# %%
new_df=new_df.drop(columns=['total_toWorld_trade'])
new_df = new_df.rename(columns={'total_trade_x': 'total_trade', 'total_trade_y': 'total_toWorld_trade'})
new_df
# Out:
#            Country  Year  GDP Growth Pct  Trade Pct GDP  TradePctGDPChange  \
# 0        Australia  2020       -0.003837      44.039526          -1.805514
# 1        Australia  2020       -0.003837      44.039526          -1.805514
# 2           Brazil  2020       -4.059048      32.354296           3.898359
# 3           Brazil  2020       -4.059048      32.354296           3.898359
# 4           Canada  2020       -5.233024      60.782530          -4.629832
# 5           Canada  2020       -5.233024      60.782530          -4.629832
# 6            China  2020        2.347514      34.506888          -1.383208
# 7            China  2020        2.347514      34.506888          -1.383208
# 8           France  2020       -7.855256      57.767428          -6.374045
# 9           France  2020       -7.855256      57.767428          -6.374045
# 19           Italy  2020.0    496316.00   247111.00     -2094.00   249205.00
# 20           Japan  2020.0    134737.30    62690.00     -9357.30    72047.30
# 21           Japan  2020.0   1126362.53   591328.13     56293.54   535034.48
# 22          Mexico  2020.0     65766.00    23317.90    -19130.20    42448.10
# 23          Mexico  2020.0    769029.45   414474.26     59919.10   354555.17
# 24     Netherlands  2020.0    455981.20   126936.73   -202107.79   329044.49
# 25     Netherlands  2020.0    666288.00   419280.00    172272.00   247008.00
# 26          Russia  2020.0    186499.80   108032.00     29564.20    78467.80
# 27          Russia  2020.0    372454.41   217429.39     62404.46   155025.03
# 28    Saudi Arabia  2020.0     45372.50    17217.10    -10938.30    28155.40
# 29    Saudi Arabia  2020.0    257068.00   156037.84     55007.75   101030.08
# 30     South Korea  2020.0    105507.10    50395.50     -4716.10    55111.60
# 31     South Korea  2020.0    896222.99   505850.32    115477.69   390372.73
# 32           Spain  2020.0    245456.83   105052.68    -35351.58   140404.21
# 33           Spain  2020.0    369097.00   180775.00     -7547.00   188322.00
# 34     Switzerland  2020.0    269611.00   125244.00    -19123.00   144367.00
# 35     Switzerland  2020.0    323803.14   186881.61     49960.03   136921.60
# 36  United Kingdom  2020.0    481211.00   192948.00    -95315.00   288263.00
# 37  United Kingdom  2020.0    569751.46   221113.96   -127523.66   348637.61
# 38   United States  2020.0    646947.00   231411.00   -184125.00   415536.00
# 39   United States  2020.0   2963381.90  1077966.76   -807448.43  1885415.21
#
#            isEuPartner  total_toWorld_exports  total_toWorld_imports  \
# 0       Trades with EU              263556.91              242371.78
# 1   Trades with Others              263556.91              242371.78
# 2       Trades with EU              261099.00              181156.65
# 3   Trades with Others              261099.00              181156.65
# 4       Trades with EU              411128.05              467666.57
# 5   Trades with Others              411128.05              467666.57
# 6       Trades with EU             2934550.65             1987641.61
# 7   Trades with Others             2934550.65             1987641.61
# 8   Trades with Others              781175.42              962329.80
# 9       Trades with EU              781175.42              962329.80
# 10  Trades with Others             2080323.50             1902553.59
# 11      Trades with EU             2080323.50             1902553.59
# 12      Trades with EU              306317.89              396771.94
# 13  Trades with Others              306317.89              396771.94
# 14      Trades with EU              195690.77              147970.74
# 15  Trades with Others              195690.77              147970.74
# 16      Trades with EU               14472.11               24232.17
# 17  Trades with Others               14472.11               24232.17
# 18  Trades with Others              742590.13              672551.83
# 19      Trades with EU              742590.13              672551.83
# 20      Trades with EU              724254.17              676317.92
# 21  Trades with Others              724254.17              676317.92
# 22      Trades with EU              463748.69              438049.59
# 23  Trades with Others              463748.69              438049.59
# 24  Trades with Others              992144.93              827497.28
# 25      Trades with EU              992144.93              827497.28
# 26      Trades with EU              444633.83              307608.66
# 27  Trades with Others              444633.83              307608.66
# 28      Trades with EU              191253.44              158089.00
# 29  Trades with Others              191253.44              158089.00
# 30      Trades with EU              604818.45              501557.12
# 31  Trades with Others              604818.45              501557.12
# 32  Trades with Others              475743.72              514813.88
# 33      Trades with EU              475743.72              514813.88
# 34      Trades with EU              438392.81              433146.81
# 35  Trades with Others              438392.81              433146.81
# 36      Trades with EU              572756.38              899169.08
# 37  Trades with Others              572756.38              899169.08
# 38      Trades with EU             1581491.76             2688370.61
# 39  Trades with Others             1581491.76             2688370.61
#
#     total_toWorld_net_exports  eu_target_pct_chg  total_toWorld_trade
# 0                    21185.23          -0.024954            451562.05
# 1                    21185.23           0.727530            451562.05
# 2                    79942.41          -0.006560            382452.68
# 3                    79942.41           0.607453            382452.68
# 4                   -56538.52          -0.016930            793351.08
# 5                   -56538.52           0.742175            793351.08
# 6                   946909.05          -0.009397           4176195.07
# 7                   946909.05           0.564120           4176195.07
# 8                  -181154.34          -0.122720           1091423.30
# 9                  -181154.34           0.000351           1091423.30
# 10                  177769.96          -0.100672           2543378.04
# 11                  177769.96           0.008203           2543378.04
# 12                  -90454.04          -0.012071            623513.85
# 13                  -90454.04           0.684600            623513.85
# 14                   47720.10          -0.004888            316660.76
# 15                   47720.10           0.774073            316660.76
# 16                   -9760.10          -0.002295             34245.43
# 17                   -9760.10           0.658982             34245.43
# 18                   70038.31          -0.040337            935549.62
# 19                   70038.31           0.011818            935549.62
# 20                   47936.13          -0.003381           1261099.83
# 21                   47936.13           0.708014           1261099.83
# 22                   25699.13          -0.001372            834795.45
# 23                   25699.13           0.779846            834795.45
# 24                  164647.62          -0.115576           1122269.20
# 25                  164647.62          -0.017083           1122269.20
# 26                  137025.28          -0.009024            558954.21
# 27                  137025.28           0.247200            558954.21
# 28                   33164.44          -0.004378            302440.50
# 29                   33164.44           0.605983            302440.50
# 30                  103261.45           0.000779           1001730.09
# 31                  103261.45           0.714690           1001730.09
# 32                  -39070.21          -0.124819            614553.83
# 33                  -39070.21          -0.006973            614553.83
# 34                    5246.03          -0.009769            593414.14
# 35                    5246.03           0.062180            593414.14
# 36                 -326412.71           0.040931           1050962.46
# 37                 -326412.71           0.060153           1050962.46
# 38                -1106878.83          -0.002948           3610328.90
# 39                -1106878.83           0.542508           3610328.90

# %%
new_df_aus = new_df[new_df['Country'] == 'Australia']
new_df_aus
# Out:
#      Country  Year  GDP Growth Pct  Trade Pct GDP  TradePctGDPChange  \
# 0  Australia  2020       -0.003837      44.039526          -1.805514
# 1  Australia  2020       -0.003837      44.039526          -1.805514
#
#      country    year  total_trade    exports  net_exports    imports  \
# 0  Australia  2020.0     41741.86    7769.76    -26202.34   33972.10
# 1  Australia  2020.0    409820.19  237846.50     65872.90  171973.72
#
#           isEuPartner  total_toWorld_exports  total_toWorld_imports  \
# 0      Trades with EU              263556.91              242371.78
# 1  Trades with Others              263556.91              242371.78
#
#    total_toWorld_net_exports  eu_target_pct_chg  total_toWorld_trade
# 0                   21185.23          -0.024954            451562.05
# 1                   21185.23           0.727530            451562.05

# %%
base = alt.Chart(new_df_aus).encode(
            theta=alt.Theta(field="total_trade", type="quantitative"),
            color=alt.Color(field="isEuPartner", type="nominal",
                            scale = alt.Scale(domain = ['Trades with EU', 'Trades with Others'],
                                              range = ['#265499', '#AFD097']), #'#2f6684', '#ff7c43', '#acc8df', '#665191', #2899CC', '#EEBC59'
                            legend = alt.Legend(title="Key")),
            
            tooltip=alt.Tooltip('total_trade', format="$,.0f")
        )

# %%
base_pie = base.transform_filter(
                alt.FieldEqualPredicate(field='Country', equal='Australia')
            ).mark_arc(outerRadius=(1000/35))

# %%
chart1 = base_pie
chart1
# Out:
# alt.Chart(...)

# %%
my_altair.get_altaire_multi_charts_for_EU()
# Out:
# ['Trades with EU' 'Trades with Others']
#       Country  Year  GDP Growth Pct  Trade Pct GDP  Trade/GDP ratio change  \
# 12  Australia  2020       -0.003837      44.039526               -1.805514
# 13  Australia  2020       -0.003837      44.039526               -1.805514
#
#       country    year  total_trade    exports  net_exports    imports  \
# 12  Australia  2020.0     41741.86    7769.76    -26202.34   33972.10
# 13  Australia  2020.0    409820.19  237846.50     65872.90  171973.72
#
#            isEuPartner  total_toWorld_exports  total_toWorld_imports  \
# 12      Trades with EU              263556.91              242371.78
# 13  Trades with Others              263556.91              242371.78
#
#     total_toWorld_net_exports  eu_target_pct_chg  total_toWorld_trade
# 12                   21185.23          -0.024954            451562.05
# 13                   21185.23           0.727530            451562.05
# alt.VConcatChart(...)

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'GDP Growth Pct', 'Trade Pct GDP',
#        'TradePctGDPChange', 'country', 'year', 'total_trade', 'exports',
#        'net_exports', 'imports', 'isEuPartner', 'total_toWorld_trade',
#        'total_toWorld_exports', 'total_toWorld_imports',
#        'total_toWorld_net_exports', 'eu_target_pct_chg'],
#       dtype='object')

# %%
eu_countries=['Austria','Belgium','Croatia','Czech Republic','Denmark','Finland','France','Germany','Greece','Hungary',
        'Italy','Netherlands','Poland','Portugal','Spain','Sweden','United Kingdom','European Union']
eu_df = df.loc[df['country'].isin(eu_countries)][['Trading Partner','Total Trade ($M)','Exports ($M)','Imports ($M)','country','year']]
        
#Non EU as trading stats
non_eu = eu_df.loc[~eu_df['Trading Partner'].isin(eu_countries)]
non_eu = eu_df.loc[~eu_df['Trading Partner'].isin(eu_countries)]
non_eu = non_eu.groupby(by=['country','year'])['Total Trade ($M)','Exports ($M)','Imports ($M)'].sum()
non_eu = non_eu.reset_index()
non_eu['Trading Partner'] = 'Non-EU'

eu_filtered_df = eu_df.loc[eu_df['Trading Partner']== 'European Union']
complete_df = pd.concat([non_eu, eu_filtered_df], axis = 0).reset_index()

# %%
df = my_data.load_and_clean_up_top_20_file()
df.head()

# %%
eu_countries=['Austria','Belgium','Croatia','Czech Republic','Denmark','Finland','France','Germany','Greece','Hungary',
        'Italy','Netherlands','Poland','Portugal','Spain','Sweden','United Kingdom','European Union']

# %%
eu_df = df.loc[df['country'].isin(eu_countries)][['Trading Partner','Total Trade ($M)','Exports ($M)','Imports ($M)','country','year']]
eu_df.head()

# %%
world = eu_df.loc[eu_df['Trading Partner']!='European Union']

world_df = world.groupby(by=['country','year'])['Total Trade ($M)','Exports ($M)','Imports ($M)'].sum()

world_df = world_df.reset_index()

world_df['Trading Partner'] = 'World'
world_df.head()

# %%
non_eu = eu_df.loc[~eu_df['Trading Partner'].isin(eu_countries)]
non_eu.head()

# %%
non_eu = eu_df.loc[~eu_df['Trading Partner'].isin(eu_countries)]

non_eu = non_eu.groupby(by=['country','year'])['Total Trade ($M)','Exports ($M)','Imports ($M)'].sum()

non_eu = non_eu.reset_index()

non_eu['Trading Partner'] = 'Non-EU'
non_eu[non_eu['year']==2020]

# %%
eu_filtered_df = eu_df.loc[eu_df['Trading Partner']== 'European Union']

complete_df = pd.concat([non_eu, eu_filtered_df], axis = 0).reset_index()
complete_df['year'].unique()

# %%
complete_df_1 = complete_df.loc[complete_df['year']==2020]
complete_df_1['Imports ($M)'] = 0 - complete_df_1['Imports ($M)']
complete_df_1 = complete_df_1.sort_values(by=['Trading Partner'], ascending=False)

complete_df_1

# %%
alt.Chart(complete_df_1).mark_bar().encode(
    x='country',
    y='Exports ($M)',
    color = 'Trading Partner',
    tooltip = alt.Tooltip('Exports ($M)', format="$,.0f"),
    order=alt.Order(
      # Sort the segments of the bars by this field
      'Trading Partner',
      sort='ascending'
    )
)

# %%
a = alt.Chart(complete_df_1).mark_area(opacity=1).encode(
    x='country',
    y='Exports ($M)',
    color = 'Trading Partner',
    tooltip = alt.Tooltip('Exports ($M)', format="$,.0f"),
    order=alt.Order(
      # Sort the segments of the bars by this field
      'Trading Partner',
      sort='ascending'
    )
)

b = alt.Chart(complete_df_1).mark_area(opacity=0.5).encode(
    x='country',
    y='Imports ($M)',
    color = 'Trading Partner',
    tooltip = alt.Tooltip('Imports ($M)', format="$,.0f"),
    order=alt.Order(
      # Sort the segments of the bars by this field
      'Trading Partner',
      sort='ascending'
    )
)

c = alt.layer(a, b)
              
c

# %%
line = base.mark_line(stroke='#5276A7', interpolate='monotone').encode(
    alt.Y('average(precipitation)',
          axis=alt.Axis(title='Precipitation (inches)', titleColor='#5276A7'))
)

# %%
top_20 = my_data.load_and_clean_up_WTO_file()

# %%
from vega_datasets import data

source = data.barley()
source.head()

# %%
eu_df_filtered = eu_df[['Trading Partner','country','Total Trade ($M)','year']]

# %%
eu_df_filtered.head()

# %%
exam = eu_df_filtered.pivot_table('Total Trade ($M)', ['Trading Partner','country'], 'year').reset_index()

# %%
exam['ordered-cols'] = exam.apply(lambda x: '-'.join(sorted([x['Trading Partner'],x['country']])), axis=1)
exam = exam.drop_duplicates(['ordered-cols'])
exam.columns = exam.columns.astype(str)

# %%
alt.Chart(exam).mark_rect().encode(
    x="Trading Partner:N",
    y="country:N",
    color='2020:Q'
).resolve_scale(color="independent",).properties(
    title='EU Domestic Service Trading Gross Volume'
).configure_axisY(
    titleAngle=30
)

# %%
dt = my_altair.my_data_object
world_source = dt.get_world_countries_by_iso_label()

# %%
for i in range(len(df)):
    for j in range(len(df)):
        source = df.index[i]
        partner = df.columns[j]
        df.iloc[i,j] = eu_service_import_2020[(eu_service_import_2020['Reporting Economy'] == source) & (eu_service_import_2020['Partner Economy'] == partner)]['2020'].sum()
