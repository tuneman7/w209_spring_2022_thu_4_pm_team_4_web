# %%
from libraries.import_export_data_objects import import_export_data as Import_Export_Data
from libraries.altair_renderings import AltairRenderings
from libraries.utility import Utility
import os
import altair as alt
my_altair = AltairRenderings()
my_data = Import_Export_Data()

# %%
import pandasql as psql
import pandas as pd

# %%
#Net Trade with EU for China, EU Top 20, US, Rest of World Top 20
df=my_data.get_eu_trade_data_pcts()
base1=alt.Chart(df[df["Top20group"]=='EU'])

pct12=base1.mark_line().encode(
    x=alt.X('year:N',axis=alt.Axis(title='')),
    y=alt.Y('NetTrade',axis=alt.Axis(title='T20 EU',labelExpr='"$" + datum.value / 1E6 + "U"'),scale=alt.Scale(domain=[-1000000, 1000000])),
    color='Trade Group:N'
  ).properties(height=150,width=300)

df=my_data.get_eu_trade_data_pcts()
base2=alt.Chart(df[df["Top20group"]=='US'])

pct22=base2.mark_line().encode(
    x=alt.X('year:N',axis=alt.Axis(title='')),
    y=alt.Y('NetTrade',axis=alt.Axis(title='US',labelExpr='"$" + datum.value / 1E6 + "U"'),scale=alt.Scale(domain=[-1000000, 1000000])),
    color='Trade Group:N'
  ).properties(height=150,width=300)

df=my_data.get_eu_trade_data_pcts()
base3=alt.Chart(df[df["Top20group"]=='China'])

pct32=base3.mark_line().encode(
    x=alt.X('year:N',axis=alt.Axis(title='')),
    y=alt.Y('NetTrade',axis=alt.Axis(title='China',labelExpr='"$" + datum.value / 1E6 + "U"'),scale=alt.Scale(domain=[-1000000, 1000000])),
    color='Trade Group:N'
  ).properties(height=150,width=300)

df=my_data.get_eu_trade_data_pcts()
base4=alt.Chart(df[df["Top20group"]=='RoW'])

pct42=base4.mark_line().encode(
    x=alt.X('year:N',axis=alt.Axis(title='')),
    y=alt.Y('NetTrade',axis=alt.Axis(title='RoW',labelExpr='"$" + datum.value / 1E6 + "U"'),scale=alt.Scale(domain=[-1000000, 1000000])),
    color='Trade Group:N'
  ).properties(height=150,width=300)


pct12.configure_axis(grid=False)
pct22.configure_axis(grid=False)
pct32.configure_axis(grid=False)
pct42.configure_axis(grid=False)

ntrade1=alt.vconcat(pct12,pct22)
ntrade2=alt.vconcat(pct32,pct42)

nettrade=alt.hconcat(ntrade1,ntrade2).configure_axis(grid=False)
nettrade
# Out:
# alt.HConcatChart(...)

# %%
df_set=my_data.get_nafta_world_trade_data()
df_set[df_set['Country']=='Canada']
# Out:
#    Country  Year Trading Group    Imports    Exports  Net_Exports
# 0   Canada  2014         NAFTA -293667.60  358445.60     64778.00
# 1   Canada  2014         World -535479.82  509021.76    -26458.08
# 2   Canada  2015         NAFTA -262353.30  305735.20     43381.90
# 3   Canada  2015         World -479108.87  423704.72    -55404.13
# 4   Canada  2016         NAFTA -249298.50  288276.90     38978.40
# 5   Canada  2016         World -461711.56  401584.56    -60126.89
# 6   Canada  2017         NAFTA -264353.70  310350.50     45996.80
# 7   Canada  2017         World -496056.47  440237.43    -55819.03
# 8   Canada  2018         NAFTA -279063.70  329899.50     50835.80
# 9   Canada  2018         World -529173.38  474491.74    -54681.69
# 10  Canada  2019         NAFTA -272642.40  330165.70     57523.30
# 11  Canada  2019         World -524662.65  479177.22    -45485.43
# 12  Canada  2020         NAFTA -232915.30  279207.27     46291.97
# ...

# %%
df_set=my_data.get_nafta_world_trade_data()
df_set_input=df_set[(df_set['Country']==source_country) & (df_set['Trading Group']==trade_group)]
df_set_input
# Out:
#    Country  Year Trading Group    Imports   Exports  Net_Exports
# 14  Mexico  2014         NAFTA -217642.60  321625.6    103983.00
# 16  Mexico  2015         NAFTA -208566.20  320574.3    112008.10
# 18  Mexico  2016         NAFTA -200498.90  320682.5    120183.60
# 20  Mexico  2017         NAFTA -216603.50  342788.7    126185.20
# 22  Mexico  2018         NAFTA -240196.50  376450.7    136254.20
# 24  Mexico  2019         NAFTA -228498.70  387475.4    158976.70
# 26  Mexico  2020         NAFTA -186653.27  348953.3    162300.03

# %%
#source_country='Mexico'
trade_group='NAFTA'

#NAFTA COUNTRY DROPDOWN LIST
nafta_list=['Mexico','United States','Canada']
nafta_dropdown = alt.binding_select(options= nafta_list,name="Country")
nafta_select = alt.selection_single(fields=['Country'], bind=nafta_dropdown, init={'Country': nafta_list[0]})

#TRADE GROUP DROPDOWN LIST
tg_list=['NAFTA','World']
tg_dropdown = alt.binding_select(options= tg_list,name="Trading Group")
tg_select = alt.selection_single(fields=['Trading Group'], bind=tg_dropdown, init={'Trading Group': tg_list[0]})

#df_set=my_data.get_nafta_world_trade_data()
#df_set_input=df_set[(df_set['Country']==source_country) & (df_set['Trading Group']==trade_group)]

df_set=my_data.get_nafta_world_trade_data()
df_set_input=df_set[(df_set['Trading Group']==trade_group)]

#df_set=my_data.get_nafta_world_trade_data()
#df_set_input=df_set[(df_set['Country']==source_country)]

#from altair.vegalite.v4.schema.core import Color
base = alt.Chart(df_set_input).transform_fold(['Imports','Exports'])
base2= alt.Chart(df_set_input)

bar = base.mark_bar(size=(35)).encode(
    x=alt.X('Year:N',axis=alt.Axis(title='Year')),
    y=alt.Y('value:Q',axis=alt.Axis(title="Trade",labelExpr='"$" + datum.value / 1E3 + "B"')),#,
    #strokeWidth=alt.value(3)
    color=alt.Color("key:N",scale=alt.Scale(scheme='blues'))
).add_selection(
            nafta_select
        ).transform_filter(
            nafta_select).properties(
    width=500,
    height=250
    )

#base2= alt.Chart(df_set_input).transform_fold(['Net Exports'])
#line = base2.mark_line(color='green').encode(
 #   x=alt.X('Year:N'),#,axis=alt.Axis(title='Year')),
 #   y=alt.Y('value:Q'),#,axis=alt.Axis(title="Trade")),#,
  #  strokeWidth=alt.value(1)
#).add_selection(
 #          nafta_select
  #      ).transform_filter(
   #         nafta_select).properties(width=500,height=250)
#,line
#,line
#line
return_chart=alt.layer(bar).configure_axis(grid=False)
return_chart
# Out:
# alt.LayerChart(...)

# %%
charts=my_altair.get_nafta_world_trade_chart('NAFTA')
charts
# Out:
# alt.LayerChart(...)

# %%
#Exchange Rate Chart
gdp=my_data.get_gdp_all_data()
gdp_c=gdp[gdp.Country.isin(['United States','Germany','China','Brazil','United Kingdom','Canada'])]
gdp_c=gdp[gdp.Country.isin(['Germany'])]
base=alt.Chart(gdp_c)

exchange_rate=base.mark_line().encode(
    x=alt.X('Year:N'),
    y=alt.Y('exchange_rate:Q',axis=alt.Axis(title='Euro to $USD Exchange Rate',format='$.2f')),
    color='Country:N'
    ).properties(height=125,width=500)

exchange_rate
# Out:
# alt.Chart(...)

# %%
#Create European Union version
#Update to Not Duplicate EU and Countries
italy=my_altair.get_altaire_bar_top5_partners_for_matrix('Italy')
france=my_altair.get_altaire_bar_top5_partners_for_matrix('France')
france | italy
# Out:
# alt.HConcatChart(...)

# %%
#Attempt to show trending EU internal trade vs World
#Would like to find a better way to do this
df=my_data.get_eu_trade_data_pcts()

baseq=alt.Chart(df)

pct1=baseq.mark_bar().encode(
    alt.Column('year'),
    x=alt.X('Top20group:N',axis=alt.Axis(title='')),
    y=alt.Y('EUvsWorld Imports %:Q',axis=alt.Axis(title='Imports',labelExpr='datum.value + "%"')),
    color='Trade Group:N'
  ).properties(height=125,width=50)

pct2=baseq.mark_bar().encode(
    alt.Column('year'),
    x=alt.X('Top20group:N',axis=alt.Axis(title='')),
    y=alt.Y('EUvsWorld Exports %:Q',axis=alt.Axis(title='Exports',labelExpr='datum.value + "%"')),
    color='Trade Group:N'
  ).properties(height=125,width=50)


pct1
pct2
# Out:
# alt.Chart(...)

# %%
#GDP Growth Chart with option to input EU country to compare to growth of other larger countries
gdp_growth=my_data.get_gdp_data_growth_rate('1')
gdp_growth

base=alt.Chart(gdp_growth)

continent=base.mark_line().encode(
    x=alt.X('Year:N'),
    y=alt.Y('Avg GDP Pct Growth:Q'),
    color='Continental:N'
    ).properties(height=300,width=600)

continent.configure_axis(grid=False)
# Out:
# alt.Chart(...)

# %%
my_altair.get_trade_group_gdp_growth_chart('NAFTA')
# Out:
# alt.Chart(...)

# %%
row_1 = (pct1 | france).resolve_scale(
            color='independent')
row_2 = (pct2 | italy).resolve_scale(
            color='independent')

#row_2 = (pct2 | italy)
#row_3 = continent.resolve_scale(
      #      color='independent')


my_chart = (row_1).configure_axis(
grid=False
).configure_view(
strokeWidth=0
)

my_chart
# Out:
# alt.HConcatChart(...)

# %%
#Function Ready to Go
df_gdp_nafta=my_data.get_gdp_data_by_country('Mexico')

base = alt.Chart(df_gdp_nafta)

title='GDP per Capita Local Currency Unit'

bar = base.mark_bar().encode(
    x=alt.X('Year:N',axis=alt.Axis(title='Year')),
    #y=alt.Y('GDP per capita:Q',axis=alt.Axis(title="GDP Per Capita $"))#,
    y=alt.Y('GDP per capita constant LCU',axis=alt.Axis(title="GDP Per Capita LCU $"))#,
    #color="Country:N"

).properties(
    width=700,
    height=350,
    title=title
    )

#Throw points on so that the tool tips will work better.
points = base.mark_circle(
    color='red',
    opacity=0.0,
    size=1000
).encode(
    x=alt.X('Year:N',axis=alt.Axis(title='')),
    y=alt.Y('GDP per capita:Q',axis=alt.Axis(title='')),
    tooltip=['GDP per capita:Q','GDP $B']
).properties(width=700)

return_chart = alt.layer(bar,points).configure_axis(grid=False)
return_chart
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4952/1862170701.py in <module>
#       1 #Function Ready to Go
# ----> 2 df_gdp_nafta=my_data.get_gdp_data_by_country('Mexico')
#       3
#       4 base = alt.Chart(df_gdp_nafta)
#       5
#
# NameError: name 'my_data' is not defined

# %%
growth=my_altair.get_trade_group_gdp_growth_chart('NAFTA')
mexico=my_altair.get_gdp_per_cap_lcu_chart('Mexico')
us=my_altair.get_gdp_per_cap_lcu_chart('United States')
canada=my_altair.get_gdp_per_cap_lcu_chart('Canada')

# %%
#US will Start NAFTA Charts tomorrow morning
us=my_altair.get_altaire_bar_top5_partners_for_matrix('United States')
mexico=my_altair.get_altaire_bar_top5_partners_for_matrix('Mexico')
canada=my_altair.get_altaire_bar_top5_partners_for_matrix('Canada')
us | mexico | canada
# Out:
# alt.HConcatChart(...)

# %%
my_data.get_gdp_all_data().columns
test=my_data.get_trade_region_map_data()
test[test.Country=='United States']
# Out:
#           Country  Year  GDP per capita  Population           GDP   GDP $B  \
# 20  United States  2020           63593   329484123  2.095303e+13  $20953B
#
#    Trade Group Map  Top 20
# 20           NAFTA  Top 20

# %%
#GDP Growth Chart with option to input EU country to compare to growth of other larger countries
#Need to update data
gdp_growth=my_data.get_gdp_data_growth_rate('1')
gdp_growth

base=alt.Chart(gdp_growth)

continent=base.mark_line().encode(
    x=alt.X('Year:N'),
    y=alt.Y('Avg GDP Pct Growth:Q'),
    color='Continental:N'
    ).properties(height=200,width=500)

continent.configure_axis(grid=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15028/3274237970.py in <module>
#       1 #GDP Growth Chart with option to input EU country to compare to growth of other larger countries
#       2 #Need to update data
# ----> 3 gdp_growth=my_data.get_gdp_data_growth_rate('1')
#       4 gdp_growth
#       5
#
# AttributeError: 'import_export_data' object has no attribute 'get_gdp_data_growth_rate'

# %%
def get_trade_group_gdp_growth_chart(self,trade_group):

    trade_group=trade_group
    if trade_group=='NAFTA':
        nafta_gdp_growth=my_data.get_nafta_gdp_data_growth_rate()
        base=alt.Chart(nafta_gdp_growth)

    else:# trade_group='EU':
        gdp_growth=my_data.get_eu_gdp_data_growth_rate('1')
        base=alt.Chart(gdp_growth)

    continent=base.mark_line().encode(
        x=alt.X('Year:N'),
        y=alt.Y('GDP Pct Growth:Q'),
        color='Continental:N'
        )

    return_chart=continent.properties(height=400,width=500).configure_axis(grid=False)
    return return_chart
# Out:
# alt.Chart(...)

# %%
trade_group=trade_group
if trade_group=='NAFTA':
    nafta_gdp_growth=my_data.get_nafta_gdp_data_growth_rate()
    base=alt.Chart(nafta_gdp_growth)

else:# trade_group='EU':
    gdp_growth=my_data.get_eu_gdp_data_growth_rate('1')
    base=alt.Chart(gdp_growth)

continent=base.mark_line().encode(
    x=alt.X('Year:N'),
    y=alt.Y('GDP Pct Growth:Q'),
    color='Continental:N'
    )

return_chart=continent.properties(height=400,width=500).configure_axis(grid=False)
return return_chart
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19280/564114128.py in <module>
# ----> 1 trade_group=trade_group
#       2 if trade_group=='NAFTA':
#       3     nafta_gdp_growth=my_data.get_nafta_gdp_data_growth_rate()
#       4     base=alt.Chart(nafta_gdp_growth)
#       5
#
# NameError: name 'trade_group' is not defined

# %%
#Exchange Rate Chart
#Function ready to go
gdp=my_data.get_gdp_all_data()
gdp_c=gdp[gdp.Country.isin(['United States','Mexico','Canada'])]
gdp_c=gdp[gdp.Country.isin(['Mexico'])]
base=alt.Chart(gdp_c)

exchange_rate=base.mark_line().encode(
    x=alt.X('Year:N'),
    y=alt.Y('exchange_rate:Q',axis=alt.Axis(title='Local Currency to $USD Exchange Rate',format='.2f')),
    color='Country:N'
    ).properties(height=200,width=500)

exchange_rate
# Out:
# alt.Chart(...)

# %%
from libraries.import_export_data_objects import import_export_data as Import_Export_Data
from libraries.altair_renderings import AltairRenderings
from libraries.utility import Utility
import os
import altair as alt
my_altair = AltairRenderings()
my_data = Import_Export_Data()

# %%
df_nafta=my_data.get_nafta_trade_data_pcts()
df_nafta_n=df_nafta[df_nafta['Top20group']=='NAFTA']

title="Inter NAFTA vs World Trade"

base=alt.Chart(df_nafta_n)

gnafta1=base.mark_bar(color='greens').encode(
    alt.Column('year'),
    x=alt.X('Trade Group:N',axis=alt.Axis(title='')),
    y=alt.Y('TotalTrade:Q'),
    color='Trade Group:N'
  ).properties(title=title,height=250,width=40)

gnafta1
# Out:
# alt.Chart(...)

# %%
my_altair.get_nafta_trade_data_pcts()
# Out:
# alt.Chart(...)

# %%
df_nafta=my_data.get_nafta_trade_data_pcts()
df_nafta_n=df_nafta[df_nafta['Top20group']=='NAFTA']

base1=alt.Chart(df_nafta)

pct1=base1.mark_bar().encode(
    alt.Column('year'),
    x=alt.X('Top20group:N',axis=alt.Axis(title='')),
    y=alt.Y('NAFTA Total Trade %'),
    color='Trade Group:N'
  ).properties(height=90,width=40)

base2=alt.Chart(df_nafta_n)

pct2=base2.mark_bar().encode(
    alt.Column('year'),
    x=alt.X('Top20group:N',axis=alt.Axis(title='')),
    y=alt.Y('NAFTA Total Trade %'),
    color='Trade Group:N'
  ).properties(height=90,width=40)

pct1.configure_axis(grid=False)
pct2.configure_axis(grid=False)

alt.vconcat(pct1 & pct2)
# Out:
# alt.VConcatChart(...)

# %%
# Out:
# alt.HConcatChart(...)

# %%
my_altair.get_net_trade_chart("Mexico") #,"world" ,#NAFTA
# Out:
# alt.LayerChart(...)

# %%
#US will Start NAFTA Charts tomorrow morning
us=my_altair.get_altaire_bar_top5_partners_for_matrix('United States')
mexico=my_altair.get_altaire_bar_top5_partners_for_matrix('Mexico')
canada=my_altair.get_altaire_bar_top5_partners_for_matrix('Canada')
us | mexico | canada
# Out:
# alt.HConcatChart(...)

# %%
us_t5=my_altair.get_import_export_balance_top_five('United States')
# Out:
# alt.LayerChart(...)

# %%
#Build Inter
def get_total_trade_compare_chart(self,source_country,width=40,height=250):
    df_nafta=my_data.get_nafta_trade_data_pcts()
    df_nafta_n=df_nafta[df_nafta['Top20group']=='NAFTA']

    title="Inter NAFTA vs World Trade"

    base=alt.Chart(df_nafta_n)

    gnafta1=base.mark_bar().encode(
        alt.Column('year'),
        x=alt.X('Trade Group:N',axis=alt.Axis(title='')),
        y=alt.Y('TotalTrade:Q'),
        color='Trade Group:N'
      ).properties(title=title,height=250,width=40)

gnafta1
# Out:
# alt.Chart(...)

# %%
my_altair.get_nafta_net_trade_chart('Canada')
#Mexico
#Mexico Nafta
#United States
#United States Nafta
#Canada
#Canada United States
# Out:
# alt.LayerChart(...)

# %%
my_altair.get_nafta_net_trade_chart('Canada')
# Out:
# alt.LayerChart(...)

# %%
get_nafta_world_trade_data():

    top20tradedata=my_data.load_and_clean_up_top_20_file()
    top20tradedata

    nafta_countries=['United States','Mexico','Canada']
    nafta_countries=pd.DataFrame(nafta_countries)
    nafta_countries.columns=['Country']
    nafta_countries
    top20tradedata

    my_sql = '''
            select
            t.*
            from
            (
            select
                Country,
                'World' [Trading Partner],
                sum([Imports ($M)]*-1) Imports,
                sum([Exports ($M)]) Exports,
                sum([Net Exports ($M)]) Net_Exports
                from top20tradedata
                where Country in (select Country from nafta_countries)
                group by [Country], [Trading Partner]
            union
            select
                Country,
                'NAFTA' [Trading Partner],
                sum(case WHEN [Trading Partner] in (select Country from nafta_countries) then [Imports ($M)]*-1 else 0 end) Imports,
                sum(case WHEN [Trading Partner] in (select Country from nafta_countries) then [Exports ($M)] else 0 end) Exports,
                sum(case WHEN [Trading Partner] in (select Country from nafta_countries) then [Net Exports ($M)] else 0 end) Net_Exports
                from top20tradedata
                where Country in (select Country from nafta_countries)
                group by [Country], [Trading Partner]
            ) t
            '''

my_return_data = psql.sqldf(my_sql)
my_return_data
# Out:
#   File "C:\Users\justi\AppData\Local\Temp/ipykernel_9180/4202420214.py", line 1
#     get_nafta_world_trade_data():
#                                  ^
# SyntaxError: invalid syntax

# %%
global ALL_COUNTRIES_DATA_FRAME

ALL_COUNTRIES_DATA_FRAME=my_data.load_and_clean_up_top_20_file()

nafta_countries=['United States','Mexico','Canada']
nafta_countries=pd.DataFrame(nafta_countries)
nafta_countries.columns=['Country']
nafta_countries

my_data_frame = ALL_COUNTRIES_DATA_FRAME

my_sql = '''
        select
        t.*
        from
        (
        select
            Country,
            'World' [Trading Partner],
            sum([Imports ($M)]*-1) Imports,
            sum([Exports ($M)]) Exports,
            sum([Net Exports ($M)]) Net_Exports
            from my_data_frame
            where Country in (select Country from nafta_countries)
            group by [Country], [Trading Partner]
        union
        select
            Country,
            'NAFTA' [Trading Partner],
            sum(case WHEN [Trading Partner] in (select Country from nafta_countries) then [Imports ($M)]*-1 else 0 end) Imports,
            sum(case WHEN [Trading Partner] in (select Country from nafta_countries) then [Exports ($M)] else 0 end) Exports,
            sum(case WHEN [Trading Partner] in (select Country from nafta_countries) then [Net Exports ($M)] else 0 end) Net_Exports
            from my_data_frame
            where Country in (select Country from nafta_countries)
            group by [Country], [Trading Partner]
        ) t
        '''

my_return_data = psql.sqldf(my_sql)
my_return_data
# Out:
#            Country Trading Partner     Imports     Exports  Net_Exports
# 0           Canada           NAFTA -1662803.00  2129629.00    466826.00
# 1           Canada           NAFTA  -191491.50    72451.67   -119039.83
# 2           Canada           NAFTA        0.00        0.00         0.00
# 3           Canada           World -1662803.00  2129629.00    466826.00
# 4           Canada           World  -401410.00   156546.20   -244863.80
# ..             ...             ...         ...         ...          ...
# 534  United States           World       -6.30       16.71        10.40
# 535  United States           World       -6.20      429.58       423.38
# 536  United States           World       -6.01       82.75        76.73
# 537  United States           World       -0.11        5.62         5.52
# 538  United States           World        0.00       30.51        30.51
#
# [539 rows x 5 columns]

# %%
top20tradedata=my_data.load_and_clean_up_top_20_file()
top20tradedata

nafta_countries=['United States','Mexico','Canada']
nafta_countries=pd.DataFrame(nafta_countries)
nafta_countries.columns=['Country']
nafta_countries
top20tradedata

my_sql = '''
select
            Country,
            'World' [Trading Partner],
            sum(['Imports ($M)']*-1) Imports,
            sum(['Exports ($M)']) Exports,
            sum(['Net Exports ($M)']) Net_Exports
            from top20tradedata
            where Country in (select country from nafta_countries)
            group by [Country], [Trading Partner]
'''

my_return_data = psql.sqldf(my_sql)
my_return_data

# %%
top20tradedata=my_data.load_and_clean_up_top_20_file()
top20tradedata
# Out:
#            Trading Partner  Total Trade ($M)  RtW (%)  Exports ($M)  \
# 0                    China         139714.00    28.28      90132.20
# 1                    Japan          64576.70    13.07      48127.30
# 2           European Union          54871.20    11.11      12268.60
# 3            United States          36313.10     7.35      10671.80
# 4              South Korea          31668.50     6.41      20413.10
# ...                    ...               ...      ...           ...
# 24388               Gambia             12.03     0.00         10.96
# 24389              Vanuatu             11.70     0.00          6.59
# 24390      Solomon Islands              8.57     0.00          5.24
# 24391              Comoros              5.67     0.00          2.25
# 24392  Sao Tome & Principe              1.60     0.00          0.69
#
#        RtW (%).1  Imports ($M)  RtW (%).2  Net Exports ($M)  Exports Ticker  \
# ...

# %%
#NAFTA CHART
#gnafta1
#trade=my_altair.get_net_trade_chart("Mexico") #,"world" ,#NAFTA

#US will Start NAFTA Charts tomorrow morning
us=my_altair.get_altaire_bar_top5_partners_for_matrix('United States')
mexico=my_altair.get_altaire_bar_top5_partners_for_matrix('Mexico')
canada=my_altair.get_altaire_bar_top5_partners_for_matrix('Canada')

us | mexico | canada
# Out:
# alt.HConcatChart(...)

# %%
my_altair.get_import_export_balance_top_five('United States')
# Out:
# alt.LayerChart(...)

# %%
#Function Ready to Go

def get_gdp_per_capita_chart(self,source_country)
        df_gdp_nafta=my_data.get_gdp_data_by_country('United States')
        base = alt.Chart(df_gdp_nafta)

        title='GDP per Capita'

        bar = base.mark_bar().encode(
            x=alt.X('Year:N',axis=alt.Axis(title='Year')),
            y=alt.Y('GDP per capita:Q',axis=alt.Axis(title="GDP Per Capita $"))#,
            #color="Country:N"

        ).properties(
            width=700,
            height=350,
            title=title
            )

        #Throw points on so that the tool tips will work better.
        points = base.mark_circle(
            color='red',
            opacity=0.0,
            size=1000
        ).encode(
            x=alt.X('Year:N',axis=alt.Axis(title='')),
            y=alt.Y('GDP per capita:Q',axis=alt.Axis(title='')),
            tooltip=['GDP per capita:Q','GDP $B']
        ).properties(width=700)

        return_chart = alt.layer(bar,points).configure_axis(grid=False)
        return return_chart
# Out:
# alt.LayerChart(...)

# %%
trade_group='NAFTA'
if trade_group=='NAFTA':
    nafta_gdp_growth=my_data.get_nafta_gdp_data_growth_rate()
    base=alt.Chart(nafta_gdp_growth)

else:# trade_group='EU':
    gdp_growth=my_data.get_eu_gdp_data_growth_rate('1')
    base=alt.Chart(gdp_growth)
    
continent=base.mark_line().encode(
    x=alt.X('Year:N'),
    y=alt.Y('GDP Pct Growth:Q'),
    color='Continental:N'
    )

return_chart=continent.properties(height=400,width=500).configure_axis(grid=False)
return return_chart
# Out:
# alt.Chart(...)

# %%
my_altair.get_exchange_rate_chart('Mexico',width=500,height=250)
# Out:
# alt.Chart(...)

# %%
#Imports and Exports
mychart=my_altair.get_import_export_type_chart('Canada')
mychart
# Out:
# alt.HConcatChart(...)

# %%
gnafta1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9828/3115151211.py in <module>
# ----> 1 gnafta1
#
# NameError: name 'gnafta1' is not defined

# %%
my_altair.get_net_trade_chart('Mexico')
# Out:
# alt.LayerChart(...)

# %%
dataframe_ie=my_data.imports_exports_by_sectors_source('United States','exports')
dataframe_ie['Year Trade Rank']=dataframe_ie.groupby(['Year'])['Value'].rank(ascending=False)
dataframe_ie_top5=dataframe_ie[dataframe_ie['Year Trade Rank']<=5]
dataframe_ie_top5

baseexp_t5=alt.Chart(dataframe_ie_top5)

title='Imports and Exports by Product/Sector'

exp_top5=baseexp_t5.mark_bar().encode(
    x=alt.X('Year:N',axis=alt.Axis(title='')),
    y=alt.Y('Value:Q'),
    color='Product/Sector-reformatted:N'
).properties(height=200,width=300)
# Out:
#      Year     Value              Product/Sector-reformatted         Type  \
# 0    2014  182413.0                   Agricultural products  merchandise
# 1    2014  201659.0               Fuels and mining products  merchandise
# 2    2014   19993.0                          Iron and steel  merchandise
# 3    2014  211822.0                               Chemicals  merchandise
# 4    2014  552090.0       Machinery and transport equipment  merchandise
# ..    ...       ...                                     ...          ...
# 149  2019  312172.0               Other commercial services     services
# 150  2020    6090.0  Maintenance and repair services n.i.e.     services
# 151  2020   72411.0                               Transport     services
# 152  2020   35808.0                                  Travel     services
# 153  2020  321439.0               Other commercial services     services
#
#     Reporting Economy
# 0       United States
# 1       United States
# ...

# %%
imp_chart | exp_chart
gnafta1 | pct1

# %%
#SCRAP DO NOT NEED
my_altair.get_time_series_gdp_chart("United States")
my_data.get_eu_trade_data_pcts()
#my_data.imports_exports_by_sectors('Germany', 'United States', 'exports')
my_data.get_top5data_by_imports_exports('Germany','exports')
my_data_frame=my_data.get_gdp_all_data()
my_data_frame
my_altair.get_time_series_gdp_compare_chart("United States","Japan")
my_altair.get_time_series_gdp_trade_trend_chart("United States")
my_altair.get_time_series_gdp_trade_trend_chart("Germany")
my_data.get_gdp_all_data()
all_gdp=my_data.get_gdp_all_data()
my_altair.get_time_series_gdp_trade_for_matrix("Japan")
print(all_gdp.columns)

# %%
from libraries.import_export_data_objects import import_export_data as Import_Export_Data
from libraries.altair_renderings import AltairRenderings
from libraries.utility import Utility
import os
import altair as alt
my_altair = AltairRenderings()
my_data = Import_Export_Data()

source_country = "United States"
target_country = "China"

#First drop down
my_chart = my_altair.get_charts_for_click_from_world_map(source_country)
my_chart

#Second drop down
my_chart = my_altair.get_charts_for_country_dill_down(source_country,target_country,width=350,height=200)
my_chart

# %%
source_country="United States"
target_country="China"

top_5  = my_altair.get_altaire_bar_top5_partners_for_matrix(source_country)
trade  = my_altair.get_import_export_balance_top_five(source_country,for_matrix=True)
time_s = my_altair.get_altaire_line_chart_county_trade_for_matrix(source_country,"World")
#gdp = my_altair.get_time_series_gdp_chart_for_matrix(source_country)#,width=width,height=height)
gdp = my_altair.get_time_series_gdp_trade_for_matrix(source_country)

row_1 = (time_s | top_5).resolve_scale(
            color='independent')
row_2 = (trade | gdp).resolve_scale(
            color='independent')

my_chart = (row_1 & row_2 ).configure_axis(
        grid=False
        ).configure_view(
        strokeWidth=0
        )

my_chart
# Out:
# alt.VConcatChart(...)
